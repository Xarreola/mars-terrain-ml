# %%
import numpy as np
import os

# Raw string paths for Windows compatibility
data_folder = r"D:\MARS FILES\ultimateMOLA_topography"
output_folder = r"D:\MARS FILES\ultimateMOLA_topography\cropped_files"

# Define bounding box for the Tharsis region (in Mars-centric degrees)
min_lon, max_lon = 230, 255   # 130°W to 105°W
min_lat, max_lat = -17, 10    # Bottom of Olympus Mons to top of Tharsis

# Make sure output folder exists
os.makedirs(output_folder, exist_ok=True)

# List all .d files in the folder
d_files = [f for f in os.listdir(data_folder) if f.endswith('.d')]

for file_name in d_files:
    file_path = os.path.join(data_folder, file_name)
    
    # Read binary data: 3-column, Big Endian Double (8 bytes per value)
    data = np.fromfile(file_path, dtype='>f8')  # Big endian float64
    data = data.reshape(-1, 3)  # Reshape into (N, 3): lon, lat, elevation

    # Filter by bounding box
    filtered = data[
        (data[:, 0] >= min_lon) & (data[:, 0] <= max_lon) &
        (data[:, 1] >= min_lat) & (data[:, 1] <= max_lat)
    ]

    if filtered.size > 0:
        # Save to new binary file
        output_path = os.path.join(output_folder, "cropped_" + file_name)
        filtered.astype('>f8').tofile(output_path)
        print(f"✅ Saved {len(filtered)} points to {output_path}")
    else:
        print(f"⚠️ No points in bounding box for {file_name}")
# Out:
# ✅ Saved 10340 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap01578l.d
# ✅ Saved 5271 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap01593l.d
# ✅ Saved 10346 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap01608l.d
# ✅ Saved 10347 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap01620l.d
# ✅ Saved 9590 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap01633l.d
# ✅ Saved 4739 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap01645l.d
# ⚠️ No points in bounding box for ap01657l.d
# ✅ Saved 5159 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap01669l.d
# ✅ Saved 5158 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap01681l.d
# ✅ Saved 5141 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10012l.d
# ✅ Saved 5166 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10024l.d
# ✅ Saved 3725 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10036l.d
# ✅ Saved 5153 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10048l.d
# ✅ Saved 2319 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10061l.d
# ✅ Saved 5150 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10073l.d
# ✅ Saved 5152 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10085l.d
# ✅ Saved 6294 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10097l.d
# ✅ Saved 10350 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10110l.d
# ✅ Saved 8227 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10122l.d
# ✅ Saved 10346 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10134l.d
# ✅ Saved 8212 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10146l.d
# ✅ Saved 9419 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10159l.d
# ✅ Saved 10287 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10171l.d
# ✅ Saved 6948 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10183l.d
# ✅ Saved 5191 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10195l.d
# ⚠️ No points in bounding box for ap10207l.d
# ✅ Saved 5190 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10220l.d
# ⚠️ No points in bounding box for ap10301l.d
# ✅ Saved 10184 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10306l.d
# ✅ Saved 39 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10318l.d
# ✅ Saved 7266 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10330l.d
# ⚠️ No points in bounding box for ap10342l.d
# ✅ Saved 3349 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10354l.d
# ✅ Saved 10344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10366l.d
# ✅ Saved 10346 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10379l.d
# ✅ Saved 5966 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10391l.d
# ✅ Saved 6310 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10403l.d
# ✅ Saved 7096 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10415l.d
# ✅ Saved 10361 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10428l.d
# ✅ Saved 9349 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10440l.d
# ✅ Saved 10347 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10452l.d
# ⚠️ No points in bounding box for ap10464l.d
# ✅ Saved 5186 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10624l.d
# ✅ Saved 5168 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10636l.d
# ✅ Saved 5190 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10648l.d
# ✅ Saved 5198 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10660l.d
# ✅ Saved 5185 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10672l.d
# ✅ Saved 318 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10685l.d
# ✅ Saved 5191 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10697l.d
# ✅ Saved 3891 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10709l.d
# ✅ Saved 10215 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10721l.d
# ✅ Saved 7398 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10734l.d
# ✅ Saved 10174 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10746l.d
# ✅ Saved 5170 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10758l.d
# ✅ Saved 11297 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10770l.d
# ✅ Saved 5185 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10783l.d
# ✅ Saved 10352 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10795l.d
# ✅ Saved 8330 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10807l.d
# ✅ Saved 10350 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10819l.d
# ✅ Saved 7249 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10832l.d
# ✅ Saved 10344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10844l.d
# ✅ Saved 6924 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10856l.d
# ✅ Saved 10339 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10868l.d
# ✅ Saved 8828 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10880l.d
# ✅ Saved 7577 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10893l.d
# ✅ Saved 10348 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10905l.d
# ✅ Saved 7267 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10917l.d
# ✅ Saved 10344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10929l.d
# ✅ Saved 7683 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10942l.d
# ✅ Saved 10351 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10954l.d
# ✅ Saved 10363 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10966l.d
# ✅ Saved 6804 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10978l.d
# ✅ Saved 5140 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap10991l.d
# ✅ Saved 12442 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11003l.d
# ✅ Saved 5167 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11015l.d
# ✅ Saved 10345 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11027l.d
# ✅ Saved 8524 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11040l.d
# ✅ Saved 10387 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11052l.d
# ✅ Saved 6008 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11064l.d
# ✅ Saved 10344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11076l.d
# ✅ Saved 10395 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11089l.d
# ✅ Saved 7070 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11101l.d
# ✅ Saved 10334 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11113l.d
# ✅ Saved 9361 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11125l.d
# ✅ Saved 10360 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11137l.d
# ✅ Saved 5267 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11150l.d
# ✅ Saved 10326 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11162l.d
# ✅ Saved 10350 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11174l.d
# ✅ Saved 5909 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11186l.d
# ✅ Saved 10367 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11199l.d
# ✅ Saved 9897 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11211l.d
# ✅ Saved 5179 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11223l.d
# ✅ Saved 10344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11235l.d
# ✅ Saved 6788 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11248l.d
# ✅ Saved 9953 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11260l.d
# ✅ Saved 5869 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11272l.d
# ✅ Saved 10331 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11284l.d
# ✅ Saved 10360 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11297l.d
# ✅ Saved 8399 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11309l.d
# ✅ Saved 10333 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11321l.d
# ✅ Saved 7219 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11333l.d
# ✅ Saved 10344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11346l.d
# ✅ Saved 7391 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11358l.d
# ✅ Saved 10365 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11370l.d
# ✅ Saved 10357 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11382l.d
# ✅ Saved 6871 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11395l.d
# ✅ Saved 10377 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11407l.d
# ✅ Saved 7226 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11419l.d
# ✅ Saved 10397 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11431l.d
# ✅ Saved 5199 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11443l.d
# ✅ Saved 9847 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11456l.d
# ✅ Saved 9432 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11468l.d
# ✅ Saved 5313 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11480l.d
# ✅ Saved 10406 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11492l.d
# ✅ Saved 10385 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11505l.d
# ✅ Saved 6131 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11517l.d
# ✅ Saved 5210 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11529l.d
# ✅ Saved 10080 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11541l.d
# ✅ Saved 10401 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11554l.d
# ✅ Saved 5551 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11566l.d
# ✅ Saved 10384 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11578l.d
# ✅ Saved 10426 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11590l.d
# ✅ Saved 5847 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11603l.d
# ✅ Saved 10410 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11615l.d
# ✅ Saved 8426 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11627l.d
# ✅ Saved 10395 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11639l.d
# ✅ Saved 8387 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11652l.d
# ✅ Saved 9231 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11664l.d
# ✅ Saved 5202 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11676l.d
# ✅ Saved 9836 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11688l.d
# ✅ Saved 6056 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11701l.d
# ✅ Saved 10391 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11713l.d
# ✅ Saved 5211 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11725l.d
# ✅ Saved 5211 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11737l.d
# ✅ Saved 7221 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11749l.d
# ✅ Saved 10414 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11762l.d
# ✅ Saved 9276 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11774l.d
# ✅ Saved 10400 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11786l.d
# ✅ Saved 10419 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11798l.d
# ✅ Saved 5387 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11811l.d
# ✅ Saved 10403 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11823l.d
# ✅ Saved 5744 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11835l.d
# ✅ Saved 10389 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11847l.d
# ✅ Saved 10405 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11860l.d
# ✅ Saved 9633 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11872l.d
# ✅ Saved 10405 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11884l.d
# ✅ Saved 7201 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11896l.d
# ✅ Saved 3126 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11909l.d
# ✅ Saved 10414 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11921l.d
# ✅ Saved 6194 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11933l.d
# ✅ Saved 10404 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11945l.d
# ✅ Saved 8172 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11958l.d
# ✅ Saved 10406 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11970l.d
# ✅ Saved 8475 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11982l.d
# ✅ Saved 9203 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap11994l.d
# ✅ Saved 10402 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12007l.d
# ✅ Saved 7479 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12019l.d
# ✅ Saved 9667 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12031l.d
# ✅ Saved 6941 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12043l.d
# ✅ Saved 10394 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12056l.d
# ✅ Saved 9759 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12068l.d
# ✅ Saved 7850 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12080l.d
# ✅ Saved 10400 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12092l.d
# ✅ Saved 8756 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12104l.d
# ✅ Saved 10359 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12117l.d
# ✅ Saved 5671 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12129l.d
# ✅ Saved 5185 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12141l.d
# ✅ Saved 10380 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12153l.d
# ✅ Saved 6551 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12166l.d
# ✅ Saved 10328 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12178l.d
# ✅ Saved 10062 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12190l.d
# ✅ Saved 10399 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12202l.d
# ✅ Saved 9800 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12215l.d
# ✅ Saved 6000 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12227l.d
# ✅ Saved 10399 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12239l.d
# ✅ Saved 5259 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12251l.d
# ✅ Saved 10343 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12264l.d
# ✅ Saved 10397 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12276l.d
# ✅ Saved 4152 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12288l.d
# ✅ Saved 10226 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12300l.d
# ✅ Saved 7225 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12313l.d
# ✅ Saved 10405 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12325l.d
# ✅ Saved 6315 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12337l.d
# ✅ Saved 10364 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12349l.d
# ✅ Saved 5176 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12361l.d
# ✅ Saved 9430 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12374l.d
# ✅ Saved 8833 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12386l.d
# ✅ Saved 8679 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12398l.d
# ✅ Saved 9012 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12410l.d
# ✅ Saved 10315 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12423l.d
# ✅ Saved 7688 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12435l.d
# ✅ Saved 10373 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12447l.d
# ✅ Saved 6707 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12459l.d
# ✅ Saved 10385 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12472l.d
# ✅ Saved 9983 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12484l.d
# ✅ Saved 7632 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12496l.d
# ✅ Saved 10418 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12508l.d
# ✅ Saved 9030 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12521l.d
# ✅ Saved 10406 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12533l.d
# ✅ Saved 5374 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12545l.d
# ✅ Saved 10394 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12557l.d
# ✅ Saved 10412 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12570l.d
# ✅ Saved 6289 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12582l.d
# ✅ Saved 5208 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12594l.d
# ✅ Saved 13676 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12606l.d
# ✅ Saved 6968 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12619l.d
# ✅ Saved 5208 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12631l.d
# ✅ Saved 2517 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12643l.d
# ✅ Saved 10397 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12655l.d
# ✅ Saved 5427 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12667l.d
# ✅ Saved 10395 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12680l.d
# ✅ Saved 7461 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12692l.d
# ✅ Saved 8957 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12704l.d
# ✅ Saved 10408 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12716l.d
# ✅ Saved 7229 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12729l.d
# ✅ Saved 10308 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12741l.d
# ✅ Saved 6713 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12753l.d
# ✅ Saved 10323 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12765l.d
# ✅ Saved 10302 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12778l.d
# ✅ Saved 7457 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12790l.d
# ✅ Saved 10316 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12802l.d
# ✅ Saved 1459 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12814l.d
# ✅ Saved 5104 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12827l.d
# ✅ Saved 10346 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12839l.d
# ✅ Saved 8102 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12851l.d
# ✅ Saved 10304 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12863l.d
# ✅ Saved 6169 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12876l.d
# ✅ Saved 10324 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12888l.d
# ✅ Saved 10167 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12900l.d
# ✅ Saved 5069 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12912l.d
# ✅ Saved 5354 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12925l.d
# ✅ Saved 9541 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12937l.d
# ✅ Saved 10348 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12949l.d
# ✅ Saved 5596 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12961l.d
# ✅ Saved 5127 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12973l.d
# ✅ Saved 10302 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12986l.d
# ✅ Saved 5584 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap12998l.d
# ✅ Saved 10352 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13010l.d
# ✅ Saved 9706 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13022l.d
# ✅ Saved 5232 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13035l.d
# ✅ Saved 4548 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13047l.d
# ✅ Saved 7040 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13059l.d
# ✅ Saved 10414 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13071l.d
# ✅ Saved 6086 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13084l.d
# ✅ Saved 10407 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13096l.d
# ✅ Saved 10410 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13108l.d
# ✅ Saved 8271 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13120l.d
# ✅ Saved 10392 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13133l.d
# ✅ Saved 7247 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13145l.d
# ✅ Saved 10405 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13157l.d
# ✅ Saved 7491 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13169l.d
# ✅ Saved 10405 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13182l.d
# ✅ Saved 10418 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13194l.d
# ✅ Saved 6882 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13206l.d
# ✅ Saved 10413 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13218l.d
# ✅ Saved 7228 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13231l.d
# ✅ Saved 10405 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13243l.d
# ✅ Saved 8859 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13255l.d
# ✅ Saved 10411 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13267l.d
# ✅ Saved 5186 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13279l.d
# ✅ Saved 5558 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13292l.d
# ✅ Saved 10202 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13304l.d
# ✅ Saved 10406 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13316l.d
# ✅ Saved 6409 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13328l.d
# ✅ Saved 10410 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13341l.d
# ✅ Saved 10275 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13353l.d
# ✅ Saved 10417 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13365l.d
# ✅ Saved 6288 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13377l.d
# ✅ Saved 10398 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13390l.d
# ✅ Saved 5365 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13402l.d
# ✅ Saved 5338 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13414l.d
# ✅ Saved 10417 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13426l.d
# ✅ Saved 9018 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13439l.d
# ✅ Saved 10425 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13451l.d
# ✅ Saved 7551 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13463l.d
# ✅ Saved 9951 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13475l.d
# ✅ Saved 10407 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13488l.d
# ✅ Saved 6738 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13500l.d
# ✅ Saved 5201 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13512l.d
# ✅ Saved 10400 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13524l.d
# ✅ Saved 7606 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13537l.d
# ✅ Saved 10428 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13549l.d
# ✅ Saved 7224 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13561l.d
# ✅ Saved 10395 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13573l.d
# ✅ Saved 8175 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13585l.d
# ✅ Saved 10374 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13598l.d
# ✅ Saved 10414 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13610l.d
# ✅ Saved 6181 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13622l.d
# ✅ Saved 10415 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13634l.d
# ✅ Saved 7075 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13647l.d
# ✅ Saved 10390 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13659l.d
# ✅ Saved 9659 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13671l.d
# ✅ Saved 10413 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13683l.d
# ✅ Saved 10406 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13696l.d
# ✅ Saved 5681 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13708l.d
# ✅ Saved 10405 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13720l.d
# ✅ Saved 5505 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13732l.d
# ✅ Saved 5198 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13745l.d
# ✅ Saved 10404 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13757l.d
# ✅ Saved 9548 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13769l.d
# ✅ Saved 10420 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13781l.d
# ✅ Saved 7204 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13794l.d
# ✅ Saved 10411 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13806l.d
# ✅ Saved 10395 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13818l.d
# ✅ Saved 6282 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13830l.d
# ✅ Saved 10409 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13843l.d
# ✅ Saved 8024 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13855l.d
# ✅ Saved 10376 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13867l.d
# ✅ Saved 7458 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13879l.d
# ✅ Saved 8892 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13891l.d
# ✅ Saved 10411 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13904l.d
# ✅ Saved 7837 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13916l.d
# ✅ Saved 10395 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13928l.d
# ✅ Saved 6503 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13940l.d
# ✅ Saved 5214 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13953l.d
# ✅ Saved 5212 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13965l.d
# ✅ Saved 2148 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13977l.d
# ✅ Saved 10404 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap13989l.d
# ✅ Saved 9414 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14002l.d
# ✅ Saved 10392 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14014l.d
# ✅ Saved 10400 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14026l.d
# ✅ Saved 5467 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14038l.d
# ✅ Saved 10426 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14051l.d
# ✅ Saved 5737 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14063l.d
# ✅ Saved 10408 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14075l.d
# ✅ Saved 10406 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14087l.d
# ✅ Saved 9675 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14100l.d
# ✅ Saved 10394 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14112l.d
# ✅ Saved 7112 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14124l.d
# ✅ Saved 10399 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14136l.d
# ✅ Saved 6227 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14149l.d
# ✅ Saved 10389 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14161l.d
# ✅ Saved 10408 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14173l.d
# ✅ Saved 8007 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14185l.d
# ✅ Saved 5181 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14197l.d
# ✅ Saved 2642 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14210l.d
# ✅ Saved 3686 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14222l.d
# ✅ Saved 10401 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14234l.d
# ✅ Saved 7872 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14246l.d
# ✅ Saved 10417 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14259l.d
# ✅ Saved 6409 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14271l.d
# ✅ Saved 10384 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14283l.d
# ✅ Saved 10372 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14295l.d
# ✅ Saved 7014 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14308l.d
# ✅ Saved 10346 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14320l.d
# ✅ Saved 7043 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14332l.d
# ✅ Saved 10407 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14344l.d
# ✅ Saved 5563 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14357l.d
# ✅ Saved 10347 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14369l.d
# ✅ Saved 9858 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14381l.d
# ✅ Saved 5593 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14393l.d
# ✅ Saved 5143 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14406l.d
# ⚠️ No points in bounding box for ap14418l.d
# ⚠️ No points in bounding box for ap14431l.d
# ⚠️ No points in bounding box for ap14443l.d
# ✅ Saved 2015 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14455l.d
# ✅ Saved 10386 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14467l.d
# ✅ Saved 6313 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14479l.d
# ✅ Saved 10286 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14491l.d
# ✅ Saved 7200 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14503l.d
# ✅ Saved 3456 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14516l.d
# ✅ Saved 10339 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14528l.d
# ✅ Saved 7233 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14540l.d
# ⚠️ No points in bounding box for ap14552l.d
# ⚠️ No points in bounding box for ap14569l.d
# ✅ Saved 5208 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14577l.d
# ✅ Saved 5209 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14589l.d
# ✅ Saved 6273 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14601l.d
# ✅ Saved 10333 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14614l.d
# ✅ Saved 5790 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14626l.d
# ✅ Saved 10388 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14638l.d
# ✅ Saved 4556 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14650l.d
# ✅ Saved 9596 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14663l.d
# ✅ Saved 5187 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14675l.d
# ✅ Saved 5709 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14687l.d
# ✅ Saved 10341 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14699l.d
# ✅ Saved 10380 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14712l.d
# ✅ Saved 5328 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14724l.d
# ✅ Saved 9996 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14736l.d
# ✅ Saved 9426 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14748l.d
# ✅ Saved 5209 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14761l.d
# ✅ Saved 6535 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14773l.d
# ✅ Saved 10246 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14785l.d
# ✅ Saved 9107 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14797l.d
# ✅ Saved 6398 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14810l.d
# ✅ Saved 10331 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14822l.d
# ✅ Saved 5210 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14834l.d
# ✅ Saved 10394 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14846l.d
# ✅ Saved 8822 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14858l.d
# ✅ Saved 5131 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14871l.d
# ✅ Saved 5201 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14883l.d
# ✅ Saved 8018 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14895l.d
# ✅ Saved 5166 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14907l.d
# ✅ Saved 9433 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14920l.d
# ✅ Saved 6261 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14932l.d
# ✅ Saved 10387 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14944l.d
# ✅ Saved 3539 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14956l.d
# ✅ Saved 6424 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14969l.d
# ✅ Saved 9690 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14981l.d
# ✅ Saved 10421 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap14993l.d
# ✅ Saved 9493 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15006l.d
# ✅ Saved 5757 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15018l.d
# ✅ Saved 10381 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15030l.d
# ✅ Saved 5434 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15042l.d
# ✅ Saved 10360 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15054l.d
# ✅ Saved 10385 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15067l.d
# ✅ Saved 9421 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15079l.d
# ✅ Saved 5215 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15091l.d
# ✅ Saved 7217 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15103l.d
# ✅ Saved 5194 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15116l.d
# ✅ Saved 10410 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15128l.d
# ✅ Saved 6456 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15140l.d
# ✅ Saved 5191 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15152l.d
# ✅ Saved 7812 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15164l.d
# ✅ Saved 10389 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15177l.d
# ✅ Saved 8403 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15189l.d
# ✅ Saved 8693 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15201l.d
# ✅ Saved 10402 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15213l.d
# ✅ Saved 8043 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15226l.d
# ✅ Saved 5174 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15238l.d
# ✅ Saved 6244 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15250l.d
# ✅ Saved 10414 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15262l.d
# ✅ Saved 10399 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15275l.d
# ✅ Saved 5130 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15287l.d
# ✅ Saved 10380 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15299l.d
# ✅ Saved 9644 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15311l.d
# ✅ Saved 10393 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15324l.d
# ✅ Saved 4605 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15336l.d
# ✅ Saved 5193 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15348l.d
# ✅ Saved 5168 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15360l.d
# ✅ Saved 5290 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15373l.d
# ✅ Saved 10371 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15385l.d
# ✅ Saved 10400 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15397l.d
# ✅ Saved 9422 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15409l.d
# ✅ Saved 10387 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15422l.d
# ✅ Saved 7201 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15434l.d
# ✅ Saved 10407 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15446l.d
# ✅ Saved 6401 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15458l.d
# ✅ Saved 10397 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15470l.d
# ✅ Saved 5185 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15483l.d
# ✅ Saved 7837 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15495l.d
# ✅ Saved 5198 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap15507l.d
# ✅ Saved 4723 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16259l.d
# ✅ Saved 7218 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16266l.d
# ✅ Saved 10356 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16278l.d
# ✅ Saved 7561 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16291l.d
# ✅ Saved 10394 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16303l.d
# ✅ Saved 10380 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16315l.d
# ✅ Saved 6808 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16327l.d
# ✅ Saved 5509 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16339l.d
# ✅ Saved 7212 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16352l.d
# ✅ Saved 10360 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16364l.d
# ✅ Saved 8567 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16376l.d
# ✅ Saved 10399 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16388l.d
# ✅ Saved 5191 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16401l.d
# ✅ Saved 5687 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16413l.d
# ✅ Saved 10348 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16425l.d
# ✅ Saved 6765 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16437l.d
# ✅ Saved 10385 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16450l.d
# ✅ Saved 9366 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16462l.d
# ✅ Saved 10355 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16474l.d
# ✅ Saved 4534 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16486l.d
# ✅ Saved 5681 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16499l.d
# ✅ Saved 10347 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16511l.d
# ✅ Saved 10340 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16523l.d
# ✅ Saved 5651 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16535l.d
# ✅ Saved 10409 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16548l.d
# ✅ Saved 9869 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16560l.d
# ✅ Saved 10334 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16572l.d
# ✅ Saved 6527 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16584l.d
# ✅ Saved 10406 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16597l.d
# ✅ Saved 10340 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16609l.d
# ✅ Saved 5520 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16621l.d
# ✅ Saved 10351 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16633l.d
# ✅ Saved 8916 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16645l.d
# ✅ Saved 10311 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16658l.d
# ✅ Saved 5203 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16670l.d
# ✅ Saved 9965 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16682l.d
# ⚠️ No points in bounding box for ap16694l.d
# ✅ Saved 6491 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16707l.d
# ✅ Saved 4610 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16719l.d
# ✅ Saved 10359 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16731l.d
# ✅ Saved 8018 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16743l.d
# ✅ Saved 10355 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16756l.d
# ✅ Saved 7273 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16768l.d
# ✅ Saved 10403 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16780l.d
# ✅ Saved 7322 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16792l.d
# ✅ Saved 10392 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16805l.d
# ✅ Saved 10385 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16817l.d
# ✅ Saved 7153 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16829l.d
# ✅ Saved 10287 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16841l.d
# ✅ Saved 7229 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16854l.d
# ✅ Saved 10380 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16866l.d
# ✅ Saved 8210 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16878l.d
# ✅ Saved 10352 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16890l.d
# ✅ Saved 10344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16903l.d
# ✅ Saved 1441 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16915l.d
# ✅ Saved 10328 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16927l.d
# ✅ Saved 7215 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16939l.d
# ✅ Saved 4579 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16951l.d
# ✅ Saved 10369 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16964l.d
# ✅ Saved 8931 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16976l.d
# ✅ Saved 10385 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap16988l.d
# ✅ Saved 5622 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17000l.d
# ✅ Saved 10386 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17013l.d
# ✅ Saved 3001 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17025l.d
# ✅ Saved 6508 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17037l.d
# ✅ Saved 9426 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17049l.d
# ✅ Saved 9684 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17062l.d
# ✅ Saved 10433 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17074l.d
# ✅ Saved 5404 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17086l.d
# ✅ Saved 10384 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17098l.d
# ✅ Saved 10423 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17110l.d
# ✅ Saved 6115 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap17123l.d
# ...
# ✅ Saved 9122 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18187l.d
# ✅ Saved 10374 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18199l.d
# ✅ Saved 3262 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18212l.d
# ✅ Saved 10400 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18224l.d
# ✅ Saved 7201 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18236l.d
# ✅ Saved 5081 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18248l.d
# ✅ Saved 6135 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18261l.d
# ✅ Saved 10246 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18273l.d
# ✅ Saved 10223 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18285l.d
# ✅ Saved 3602 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18297l.d
# ✅ Saved 5197 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18310l.d
# ✅ Saved 11639 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18322l.d
# ✅ Saved 5210 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18334l.d
# ✅ Saved 9451 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18346l.d
# ✅ Saved 5788 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18359l.d
# ✅ Saved 10252 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18371l.d
# ✅ Saved 9172 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18383l.d
# ✅ Saved 10335 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18395l.d
# ✅ Saved 6828 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18407l.d
# ✅ Saved 10370 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18420l.d
# ✅ Saved 10373 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18432l.d
# ✅ Saved 5263 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18444l.d
# ✅ Saved 10361 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18456l.d
# ✅ Saved 9829 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18469l.d
# ✅ Saved 10332 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18481l.d
# ✅ Saved 6124 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18493l.d
# ✅ Saved 10291 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18505l.d
# ✅ Saved 10319 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18518l.d
# ✅ Saved 616 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18530l.d
# ✅ Saved 5164 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18542l.d
# ✅ Saved 10084 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18554l.d
# ✅ Saved 9973 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18566l.d
# ✅ Saved 9855 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18579l.d
# ✅ Saved 5235 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18591l.d
# ✅ Saved 10266 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18603l.d
# ✅ Saved 6759 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18615l.d
# ✅ Saved 10300 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18628l.d
# ✅ Saved 9066 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18640l.d
# ✅ Saved 10264 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18652l.d
# ✅ Saved 10350 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18664l.d
# ✅ Saved 5965 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18677l.d
# ✅ Saved 10277 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18689l.d
# ✅ Saved 7344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18701l.d
# ✅ Saved 10426 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18713l.d
# ✅ Saved 2801 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18725l.d
# ✅ Saved 10340 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18738l.d
# ✅ Saved 7924 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18750l.d
# ✅ Saved 2105 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18762l.d
# ✅ Saved 4512 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18774l.d
# ✅ Saved 4445 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18787l.d
# ✅ Saved 8508 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18799l.d
# ✅ Saved 10305 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18811l.d
# ✅ Saved 5549 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18823l.d
# ✅ Saved 10332 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18836l.d
# ✅ Saved 8709 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18848l.d
# ✅ Saved 5127 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18860l.d
# ✅ Saved 7003 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18872l.d
# ✅ Saved 10339 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18885l.d
# ✅ Saved 5055 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18897l.d
# ✅ Saved 5108 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18909l.d
# ✅ Saved 10193 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18921l.d
# ✅ Saved 5148 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18933l.d
# ✅ Saved 10247 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18946l.d
# ✅ Saved 5129 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18958l.d
# ✅ Saved 10322 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18970l.d
# ✅ Saved 5138 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18982l.d
# ✅ Saved 6973 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap18995l.d
# ✅ Saved 5127 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19007l.d
# ✅ Saved 8607 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19019l.d
# ✅ Saved 10324 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19031l.d
# ✅ Saved 10248 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19043l.d
# ✅ Saved 6788 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19056l.d
# ✅ Saved 10322 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19068l.d
# ✅ Saved 7341 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19080l.d
# ✅ Saved 10233 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19092l.d
# ✅ Saved 6655 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19105l.d
# ✅ Saved 5202 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19117l.d
# ✅ Saved 10238 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19129l.d
# ✅ Saved 8843 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19141l.d
# ✅ Saved 10334 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19154l.d
# ✅ Saved 6588 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19166l.d
# ✅ Saved 10229 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19178l.d
# ✅ Saved 4915 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19190l.d
# ✅ Saved 6452 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19202l.d
# ✅ Saved 5193 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19215l.d
# ✅ Saved 15054 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19227l.d
# ✅ Saved 5203 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19239l.d
# ✅ Saved 615 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19251l.d
# ✅ Saved 10307 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19264l.d
# ✅ Saved 9726 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19276l.d
# ✅ Saved 8026 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19288l.d
# ✅ Saved 10315 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19300l.d
# ✅ Saved 7484 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19312l.d
# ✅ Saved 10329 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19325l.d
# ✅ Saved 7943 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19337l.d
# ✅ Saved 5117 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19349l.d
# ✅ Saved 7271 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19361l.d
# ✅ Saved 10162 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19374l.d
# ✅ Saved 10312 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19386l.d
# ✅ Saved 5337 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19398l.d
# ✅ Saved 5109 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19410l.d
# ✅ Saved 10174 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19423l.d
# ✅ Saved 9758 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19435l.d
# ✅ Saved 5105 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19447l.d
# ✅ Saved 5196 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19459l.d
# ✅ Saved 7681 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19471l.d
# ✅ Saved 7197 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19484l.d
# ✅ Saved 10284 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19496l.d
# ✅ Saved 8193 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19508l.d
# ✅ Saved 10293 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19520l.d
# ✅ Saved 10289 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19533l.d
# ✅ Saved 3790 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19545l.d
# ✅ Saved 10401 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19557l.d
# ✅ Saved 7454 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19569l.d
# ✅ Saved 10294 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19581l.d
# ✅ Saved 5212 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19594l.d
# ⚠️ No points in bounding box for ap19606l.d
# ⚠️ No points in bounding box for ap19699l.d
# ✅ Saved 10427 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19704l.d
# ✅ Saved 8698 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19716l.d
# ✅ Saved 10310 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19728l.d
# ✅ Saved 6886 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19740l.d
# ✅ Saved 9494 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19753l.d
# ✅ Saved 8525 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19765l.d
# ✅ Saved 9255 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19777l.d
# ✅ Saved 10386 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19789l.d
# ✅ Saved 6201 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19802l.d
# ✅ Saved 10315 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19814l.d
# ✅ Saved 9330 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19826l.d
# ✅ Saved 10286 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19838l.d
# ✅ Saved 6055 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19850l.d
# ✅ Saved 10319 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19863l.d
# ✅ Saved 10286 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19875l.d
# ✅ Saved 6487 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19887l.d
# ✅ Saved 5101 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19899l.d
# ✅ Saved 8986 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19912l.d
# ✅ Saved 5116 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19924l.d
# ✅ Saved 10334 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19936l.d
# ✅ Saved 6566 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19948l.d
# ✅ Saved 9130 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19960l.d
# ✅ Saved 7499 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19973l.d
# ✅ Saved 8918 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19985l.d
# ✅ Saved 1715 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap19997l.d
# ✅ Saved 10310 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20009l.d
# ✅ Saved 5631 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20022l.d
# ✅ Saved 9176 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20034l.d
# ✅ Saved 10407 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20046l.d
# ✅ Saved 6378 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20058l.d
# ✅ Saved 10301 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20071l.d
# ✅ Saved 6271 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20083l.d
# ✅ Saved 10426 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20095l.d
# ✅ Saved 9257 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20107l.d
# ✅ Saved 10022 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20119l.d
# ✅ Saved 5185 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20132l.d
# ✅ Saved 9399 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20144l.d
# ✅ Saved 5204 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20156l.d
# ✅ Saved 9130 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20168l.d
# ✅ Saved 5190 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20181l.d
# ✅ Saved 8344 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20193l.d
# ✅ Saved 6763 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20205l.d
# ✅ Saved 5275 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20217l.d
# ✅ Saved 3754 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20229l.d
# ✅ Saved 10434 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20242l.d
# ✅ Saved 6623 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20254l.d
# ✅ Saved 10414 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20266l.d
# ✅ Saved 10387 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20278l.d
# ✅ Saved 5207 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20291l.d
# ✅ Saved 10413 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20303l.d
# ✅ Saved 9553 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20315l.d
# ✅ Saved 5208 points to D:\MARS FILES\ultimateMOLA_topography\cropped_files\cropped_ap20327l.d

# %%
import numpy as np
import os

# Raw string paths
cropped_folder = r"D:\MARS FILES\ultimateMOLA_topography\cropped_files"
output_ply = r"D:\MARS FILES\ultimateMOLA_topography\tharsis_cropped.ply"

# Collect all cropped files
cropped_files = [f for f in os.listdir(cropped_folder) if f.startswith("cropped_") and f.endswith(".d")]

# Load and stack all filtered points
all_points = []
for file_name in cropped_files:
    file_path = os.path.join(cropped_folder, file_name)
    data = np.fromfile(file_path, dtype='>f8').reshape(-1, 3)
    all_points.append(data)

# Combine into single array
points = np.vstack(all_points)

# Write to PLY file
with open(output_ply, 'w') as f:
    f.write("ply\n")
    f.write("format ascii 1.0\n")
    f.write(f"element vertex {len(points)}\n")
    f.write("property float x\n")
    f.write("property float y\n")
    f.write("property float z\n")
    f.write("end_header\n")
    
    for lon, lat, elev in points:
        f.write(f"{lon:.6f} {lat:.6f} {elev:.2f}\n")

print(f"✅ Exported to PLY at {output_ply}")
# Out:
# ✅ Exported to PLY at D:\MARS FILES\ultimateMOLA_topography\tharsis_cropped.ply

# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import open3d as o3d  # For exporting to .PLY

# Path to your folder with all the .d files
data_folder = r"D:\MARS FILES\ultimateMOLA_topography"

# Grab all .d files
file_list = glob(os.path.join(data_folder, "*.d"))

all_points = []

for file_path in file_list:
    data = np.fromfile(file_path, dtype=">f8")  # Big-endian float64
    data = data.reshape(-1, 3)  # Each row: [lon, lat, elevation]
    
    # Optional: filter out invalid altitudes (e.g., absurd negative/positive values)
    valid = (data[:, 2] > -10000) & (data[:, 2] < 30000)
    filtered = data[valid]
    
    all_points.append(filtered)

# Combine all the filtered files
combined = np.vstack(all_points)

# Convert lon/lat/elevation into XYZ using spherical to cartesian
mars_radius = 3396000  # Approx Mars radius in meters
lon_rad = np.deg2rad(combined[:, 0])
lat_rad = np.deg2rad(combined[:, 1])
alt = combined[:, 2]

X = (mars_radius + alt) * np.cos(lat_rad) * np.cos(lon_rad)
Y = (mars_radius + alt) * np.cos(lat_rad) * np.sin(lon_rad)
Z = (mars_radius + alt) * np.sin(lat_rad)

points = np.column_stack((X, Y, Z))

# Create and save as .PLY using open3d
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)
o3d.io.write_point_cloud(r"D:\
# Out:
#   Cell In[6], line 43
#     o3d.io.write_point_cloud(r"D:\
#                              ^
# SyntaxError: incomplete input

# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import open3d as o3d  # For exporting to .PLY

# Path to your folder with all the .d files
data_folder = r"D:\MARS FILES\ultimateMOLA_topography"

# Grab all .d files
file_list = glob(os.path.join(data_folder, "*.d"))

all_points = []

for file_path in file_list:
    data = np.fromfile(file_path, dtype=">f8")  # Big-endian float64
    data = data.reshape(-1, 3)  # Each row: [lon, lat, elevation]
    
    # Optional: filter out invalid altitudes (e.g., absurd negative/positive values)
    valid = (data[:, 2] > -10000) & (data[:, 2] < 30000)
    filtered = data[valid]
    
    all_points.append(filtered)

# Combine all the filtered files
combined = np.vstack(all_points)

# Convert lon/lat/elevation into XYZ using spherical to cartesian
mars_radius = 3396000  # Approx Mars radius in meters
lon_rad = np.deg2rad(combined[:, 0])
lat_rad = np.deg2rad(combined[:, 1])
alt = combined[:, 2]

X = (mars_radius + alt) * np.cos(lat_rad) * np.cos(lon_rad)
Y = (mars_radius + alt) * np.cos(lat_rad) * np.sin(lon_rad)
Z = (mars_radius + alt) * np.sin(lat_rad)

points = np.column_stack((X, Y, Z))

# Create and save as .PLY using open3d
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)
o3d.io.write_point_cloud(r"D:\MARS FILES\mars_pointcloud.ply", pcd)  # Complete file path with filename
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 5
#       3 import pandas as pd
#       4 from glob import glob
# ----> 5 import open3d as o3d  # For exporting to .PLY
#       7 # Path to your folder with all the .d files
#       8 data_folder = r"D:\MARS FILES\ultimateMOLA_topography"
#
# ModuleNotFoundError: No module named 'open3d'

# %%
# !pip install open3d
# Out:
# Collecting open3d
#   Downloading open3d-0.19.0-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\dell\anaconda3\lib\site-packages (from open3d) (1.26.4)
# Collecting dash>=2.6.0 (from open3d)
#   Downloading dash-3.0.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: werkzeug>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from open3d) (3.0.3)
# Requirement already satisfied: flask>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from open3d) (3.0.3)
# Requirement already satisfied: nbformat>=5.7.0 in c:\users\dell\anaconda3\lib\site-packages (from open3d) (5.10.4)
# Collecting configargparse (from open3d)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Collecting ipywidgets>=8.0.4 (from open3d)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\dell\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (5.24.1)
# Requirement already satisfied: importlib-metadata in c:\users\dell\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\dell\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (4.11.0)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (2.32.3)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\dell\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (75.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\dell\anaconda3\lib\site-packages (from flask>=3.0.0->open3d) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\dell\anaconda3\lib\site-packages (from flask>=3.0.0->open3d) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\dell\anaconda3\lib\site-packages (from flask>=3.0.0->open3d) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\dell\anaconda3\lib\site-packages (from flask>=3.0.0->open3d) (1.6.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\dell\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\dell\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\dell\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets>=8.0.4->open3d)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets>=8.0.4->open3d)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\dell\anaconda3\lib\site-packages (from nbformat>=5.7.0->open3d) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\dell\anaconda3\lib\site-packages (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dell\anaconda3\lib\site-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\anaconda3\lib\site-packages (from werkzeug>=3.0.0->open3d) (2.1.3)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from click>=8.1.3->flask>=3.0.0->open3d) (0.4.6)
# Requirement already satisfied: decorator in c:\users\dell\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dell\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\dell\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\dell\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dell\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\dell\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\dell\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (305.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (8.2.3)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (24.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda3\lib\site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->dash>=2.6.0->open3d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->dash>=2.6.0->open3d) (2025.1.31)
# Requirement already satisfied: six>=1.7.0 in c:\users\dell\anaconda3\lib\site-packages (from retrying->dash>=2.6.0->open3d) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\dell\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\dell\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.5)
# Requirement already satisfied: executing in c:\users\dell\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\dell\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\dell\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.2)
# Downloading open3d-0.19.0-cp312-cp312-win_amd64.whl (69.2 MB)
#    ---------------------------------------- 0.0/69.2 MB ? eta -:--:--
#    --- ------------------------------------ 6.0/69.2 MB 30.8 MB/s eta 0:00:03
#    -------- ------------------------------- 15.2/69.2 MB 36.8 MB/s eta 0:00:02
#    -------------- ------------------------- 24.9/69.2 MB 40.5 MB/s eta 0:00:02
#    -------------------- ------------------- 34.6/69.2 MB 41.5 MB/s eta 0:00:01
#    ------------------------- -------------- 44.0/69.2 MB 42.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 51.6/69.2 MB 41.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 62.1/69.2 MB 42.1 MB/s eta 0:00:01
#    ---------------------------------------  68.9/69.2 MB 43.1 MB/s eta 0:00:01
#    ---------------------------------------- 69.2/69.2 MB 37.7 MB/s eta 0:00:00
# Downloading dash-3.0.2-py3-none-any.whl (7.9 MB)
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    ---------------------------------------  7.9/7.9 MB 44.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 35.1 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 32.9 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: widgetsnbextension, retrying, jupyterlab-widgets, configargparse, dash, ipywidgets, open3d
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.8.1
#     Uninstalling ipywidgets-7.8.1:
#       Successfully uninstalled ipywidgets-7.8.1
# Successfully installed configargparse-1.7 dash-3.0.2 ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 open3d-0.19.0 retrying-1.3.4 widgetsnbextension-4.0.13

# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import open3d as o3d  # For exporting to .PLY

# Path to your folder with all the .d files
data_folder = r"D:\MARS FILES\ultimateMOLA_topography"

# Grab all .d files
file_list = glob(os.path.join(data_folder, "*.d"))

all_points = []

for file_path in file_list:
    data = np.fromfile(file_path, dtype=">f8")  # Big-endian float64
    data = data.reshape(-1, 3)  # Each row: [lon, lat, elevation]
    
    # Optional: filter out invalid altitudes (e.g., absurd negative/positive values)
    valid = (data[:, 2] > -10000) & (data[:, 2] < 30000)
    filtered = data[valid]
    
    all_points.append(filtered)

# Combine all the filtered files
combined = np.vstack(all_points)

# Convert lon/lat/elevation into XYZ using spherical to cartesian
mars_radius = 3396000  # Approx Mars radius in meters
lon_rad = np.deg2rad(combined[:, 0])
lat_rad = np.deg2rad(combined[:, 1])
alt = combined[:, 2]

X = (mars_radius + alt) * np.cos(lat_rad) * np.cos(lon_rad)
Y = (mars_radius + alt) * np.cos(lat_rad) * np.sin(lon_rad)
Z = (mars_radius + alt) * np.sin(lat_rad)

points = np.column_stack((X, Y, Z))

# Create and save as .PLY using open3d
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)
o3d.io.write_point_cloud(r"D:\MARS FILES\mars_pointcloud.ply", pcd)  # Complete file path with filename
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import open3d as o3d  # For exporting to .PLY

# Path to your folder with all the .d files
data_folder = r"D:\MARS FILES\ultimateMOLA_topography"

# Grab all .d files
file_list = glob(os.path.join(data_folder, "*.d"))

all_points = []

for file_path in file_list:
    data = np.fromfile(file_path, dtype=">f8")  # Big-endian float64
    data = data.reshape(-1, 3)  # Each row: [lon, lat, elevation]
    
    # Optional: filter out invalid altitudes (e.g., absurd negative/positive values)
    valid = (data[:, 2] > -10000) & (data[:, 2] < 30000)
    filtered = data[valid]
    
    all_points.append(filtered)

# Combine all the filtered files
combined = np.vstack(all_points)

# Convert lon/lat/elevation into XYZ using spherical to cartesian
mars_radius = 3396000  # Approx Mars radius in meters
lon_rad = np.deg2rad(combined[:, 0])
lat_rad = np.deg2rad(combined[:, 1])
alt = combined[:, 2]

X = (mars_radius + alt) * np.cos(lat_rad) * np.cos(lon_rad)
Y = (mars_radius + alt) * np.cos(lat_rad) * np.sin(lon_rad)
Z = (mars_radius + alt) * np.sin(lat_rad)

points = np.column_stack((X, Y, Z))

# Create and save as .PLY using open3d
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)
o3d.io.write_point_cloud(r"D:\MARS FILES\ultimateMOLA_topography\full_topography.ply", pcd)

print("✅ Export complete! File saved as 'full_topography.ply'")

# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import open3d as o3d  # For exporting to .PLY

# Path to your folder with all the .d files
data_folder = r"D:\MARS FILES\ultimateMOLA_topography"

# Grab all .d files
file_list = glob(os.path.join(data_folder, "*.d"))

all_points = []

for file_path in file_list:
    data = np.fromfile(file_path, dtype=">f8")  # Big-endian float64
    data = data.reshape(-1, 3)  # Each row: [lon, lat, elevation]
    
    # Optional: filter out invalid altitudes (e.g., absurd negative/positive values)
    valid = (data[:, 2] > -10000) & (data[:, 2] < 30000)
    filtered = data[valid]
    
    all_points.append(filtered)

# Combine all the filtered files
combined = np.vstack(all_points)

# Convert lon/lat/elevation into XYZ using spherical to cartesian
mars_radius = 3396000  # Approx Mars radius in meters
lon_rad = np.deg2rad(combined[:, 0])
lat_rad = np.deg2rad(combined[:, 1])
alt = combined[:, 2]

X = (mars_radius + alt) * np.cos(lat_rad) * np.cos(lon_rad)
Y = (mars_radius + alt) * np.cos(lat_rad) * np.sin(lon_rad)
Z = (mars_radius + alt) * np.sin(lat_rad)

points = np.column_stack((X, Y, Z))

# Create and save as .PLY using open3d
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)
o3d.io.write_point_cloud(r"D:\MARS FILES\ultimateMOLA_topography\full_topography.ply", pcd)

print("✅ Export complete! File saved as 'full_topography.ply'")
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14984\766933474.py:30: RuntimeWarning: invalid value encountered in deg2rad
#   lon_rad = np.deg2rad(combined[:, 0])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14984\766933474.py:31: RuntimeWarning: invalid value encountered in deg2rad
#   lat_rad = np.deg2rad(combined[:, 1])
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 34
#      31 lat_rad = np.deg2rad(combined[:, 1])
#      32 alt = combined[:, 2]
# ---> 34 X = (mars_radius + alt) * np.cos(lat_rad) * np.cos(lon_rad)
#      35 Y = (mars_radius + alt) * np.cos(lat_rad) * np.sin(lon_rad)
#      36 Z = (mars_radius + alt) * np.sin(lat_rad)
#
# MemoryError: Unable to allocate 4.31 GiB for an array with shape (578099394,) and data type float64

# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import open3d as o3d
import sys
import traceback
from datetime import datetime

# Path to your folder with all the .d files
data_folder = r"D:\MARS FILES\ultimateMOLA_topography"
output_folder = os.path.join(data_folder, "split_topography")

# Create output directory if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Created output directory: {output_folder}")

try:
    # Grab all .d files
    file_list = glob(os.path.join(data_folder, "*.d"))
    print(f"Found {len(file_list)} .d files to process")
    
    all_points = []
    
    for i, file_path in enumerate(file_list):
        if i % 10 == 0:  # Progress update every 10 files
            print(f"Processing file {i+1}/{len(file_list)}")
        data = np.fromfile(file_path, dtype=">f8")  # Big-endian float64
        data = data.reshape(-1, 3)  # Each row: [lon, lat, elevation]
        
        # Optional: filter out invalid altitudes
        valid = (data[:, 2] > -10000) & (data[:, 2] < 30000)
        filtered = data[valid]
        
        all_points.append(filtered)
    
    # Combine all the filtered files
    combined = np.vstack(all_points)
    print(f"Combined data shape: {combined.shape}")
    
    # Convert lon/lat/elevation into XYZ using spherical to cartesian
    mars_radius = 3396000  # Approx Mars radius in meters
    lon_rad = np.deg2rad(combined[:, 0])
    lat_rad = np.deg2rad(combined[:, 1])
    alt = combined[:, 2]
    
    X = (mars_radius + alt) * np.cos(lat_rad) * np.cos(lon_rad)
    Y = (mars_radius + alt) * np.cos(lat_rad) * np.sin(lon_rad)
    Z = (mars_radius + alt) * np.sin(lat_rad)
    
    points = np.column_stack((X, Y, Z))
    print(f"Generated {len(points)} 3D points")
    
    # Split the data into 4 parts based on quadrants in the XY plane
    # This creates a natural geographical division
    quadrant_masks = [
        (X >= 0) & (Y >= 0),  # Quadrant 1: Northeast
        (X < 0) & (Y >= 0),   # Quadrant 2: Northwest
        (X < 0) & (Y < 0),    # Quadrant 3: Southwest
        (X >= 0) & (Y < 0)    # Quadrant 4: Southeast
    ]
    
    quadrant_names = ["northeast", "northwest", "southwest", "southeast"]
    
    # Create metadata file
    metadata_path = os.path.join(output_folder, "mars_topography_metadata.txt")
    with open(metadata_path, 'w') as meta_file:
        meta_file.write("MARS TOPOGRAPHY POINT CLOUD - SPLIT FILES METADATA\n")
        meta_file.write(f"Generated on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        meta_file.write(f"Original data points: {len(points)}\n")
        meta_file.write(f"Mars radius used: {mars_radius} meters\n\n")
        meta_file.write("FILE INFORMATION:\n")
        
        # Process each quadrant
        for i, (mask, name) in enumerate(zip(quadrant_masks, quadrant_names)):
            quadrant_points = points[mask]
            quadrant_original = combined[mask]
            
            # Skip if no points in this quadrant
            if len(quadrant_points) == 0:
                meta_file.write(f"Quadrant {i+1} ({name}): No points found\n")
                continue
                
            # Calculate bounding box for this quadrant
            min_x, min_y, min_z = np.min(quadrant_points, axis=0)
            max_x, max_y, max_z = np.max(quadrant_points, axis=0)
            
            # Calculate original coordinate ranges
            min_lon, min_lat, min_alt = np.min(quadrant_original, axis=0)
            max_lon, max_lat, max_alt = np.max(quadrant_original, axis=0)
            
            # Create point cloud for this quadrant
            pcd = o3d.geometry.PointCloud()
            pcd.points = o3d.utility.Vector3dVector(quadrant_points)
            
            # Save the point cloud
            output_file = os.path.join(output_folder, f"mars_topography_{name}.ply")
            success = o3d.io.write_point_cloud(output_file, pcd)
            
            if success:
                print(f"✅ Exported quadrant {i+1} ({name}) with {len(quadrant_points)} points")
                
                # Write metadata for this file
                meta_file.write(f"\nFile {i+1}: mars_topography_{name}.ply\n")
                meta_file.write(f"  Points: {len(quadrant_points)}\n")
                meta_file.write(f"  Cartesian bounds (meters):\n")
                meta_file.write(f"    X: {min_x:.2f} to {max_x:.2f}\n")
                meta_file.write(f"    Y: {min_y:.2f} to {max_y:.2f}\n")
                meta_file.write(f"    Z: {min_z:.2f} to {max_z:.2f}\n")
                meta_file.write(f"  Geographic bounds:\n")
                meta_file.write(f"    Longitude: {min_lon:.6f}° to {max_lon:.6f}°\n")
                meta_file.write(f"    Latitude: {min_lat:.6f}° to {max_lat:.6f}°\n")
                meta_file.write(f"    Altitude: {min_alt:.2f}m to {max_alt:.2f}m\n")
            else:
                print(f"❌ Failed to export quadrant {i+1} ({name})")
                meta_file.write(f"\nFile {i+1}: EXPORT FAILED for {name} quadrant\n")
    
    print(f"\n✅ Process complete! Files saved to: {output_folder}")
    print(f"✅ Metadata file created: {metadata_path}")

except Exception as e:
    print(f"❌ Error occurred: {str(e)}")
    print("Detailed traceback:")
    traceback.print_exc()
# Out:
# Created output directory: D:\MARS FILES\ultimateMOLA_topography\split_topography
# Found 770 .d files to process
# Processing file 1/770
# Processing file 11/770
# Processing file 21/770
# Processing file 31/770
# Processing file 41/770
# Processing file 51/770
# Processing file 61/770
# Processing file 71/770
# Processing file 81/770
# Processing file 91/770
# Processing file 101/770
# Processing file 111/770
# Processing file 121/770
# Processing file 131/770
# Processing file 141/770
# Processing file 151/770
# Processing file 161/770
# Processing file 171/770
# Processing file 181/770
# Processing file 191/770
# Processing file 201/770
# Processing file 211/770
# Processing file 221/770
# Processing file 231/770
# Processing file 241/770
# Processing file 251/770
# Processing file 261/770
# Processing file 271/770
# Processing file 281/770
# Processing file 291/770
# Processing file 301/770
# Processing file 311/770
# Processing file 321/770
# Processing file 331/770
# Processing file 341/770
# Processing file 351/770
# Processing file 361/770
# Processing file 371/770
# Processing file 381/770
# Processing file 391/770
# Processing file 401/770
# Processing file 411/770
# Processing file 421/770
# Processing file 431/770
# Processing file 441/770
# Processing file 451/770
# Processing file 461/770
# Processing file 471/770
# Processing file 481/770
# Processing file 491/770
# Processing file 501/770
# Processing file 511/770
# Processing file 521/770
# Processing file 531/770
# Processing file 541/770
# Processing file 551/770
# Processing file 561/770
# Processing file 571/770
# Processing file 581/770
# Processing file 591/770
# Processing file 601/770
# Processing file 611/770
# Processing file 621/770
# Processing file 631/770
# Processing file 641/770
# Processing file 651/770
# Processing file 661/770
# Processing file 671/770
# Processing file 681/770
# Processing file 691/770
# Processing file 701/770
# Processing file 711/770
# Processing file 721/770
# Processing file 731/770
# Processing file 741/770
# Processing file 751/770
# Processing file 761/770
# ❌ Error occurred: Unable to allocate 12.9 GiB for an array with shape (578099394, 3) and data type float64
# Detailed traceback:
# Traceback (most recent call last):
#   File "C:\Users\Dell\AppData\Local\Temp\ipykernel_14984\3453744583.py", line 39, in <module>
#     combined = np.vstack(all_points)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Dell\anaconda3\Lib\site-packages\numpy\core\shape_base.py", line 289, in vstack
#     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 12.9 GiB for an array with shape (578099394, 3) and data type float64

# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import open3d as o3d
import sys
import traceback
from datetime import datetime

# Path to your folder with all the .d files
data_folder = r"D:\MARS FILES\ultimateMOLA_topography"
output_folder = os.path.join(data_folder, "region_topography")

# Create output directory if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Created output directory: {output_folder}")

# Define the region of interest (Mars-centric coordinates)
min_lon = 230   # 130°W = 230°E
max_lon = 255   # 105°W = 255°E
min_lat = -17
max_lat = 10

try:
    # Grab all .d files
    file_list = glob(os.path.join(data_folder, "*.d"))
    print(f"Found {len(file_list)} .d files to process")
    
    # Process files in batches to avoid memory issues
    batch_size = 50  # Adjust based on your system's memory
    total_points = 0
    region_points = []
    
    for batch_start in range(0, len(file_list), batch_size):
        batch_end = min(batch_start + batch_size, len(file_list))
        print(f"Processing batch {batch_start//batch_size + 1}: files {batch_start+1} to {batch_end}")
        
        batch_points = []
        for i in range(batch_start, batch_end):
            file_path = file_list[i]
            data = np.fromfile(file_path, dtype=">f8")  # Big-endian float64
            data = data.reshape(-1, 3)  # Each row: [lon, lat, elevation]
            
            # Filter by region immediately to save memory
            region_mask = (
                (data[:, 0] >= min_lon) & 
                (data[:, 0] <= max_lon) & 
                (data[:, 1] >= min_lat) & 
                (data[:, 1] <= max_lat)
            )
            
            # Also filter out invalid altitudes
            valid = region_mask & (data[:, 2] > -10000) & (data[:, 2] < 30000)
            filtered = data[valid]
            
            if len(filtered) > 0:
                batch_points.append(filtered)
        
        # If we found points in this batch, process them
        if batch_points:
            batch_combined = np.vstack(batch_points)
            region_points.append(batch_combined)
            print(f"  Found {len(batch_combined)} points in region for this batch")
            total_points += len(batch_combined)
    
    # If we found any points in the region
    if region_points:
        # Combine all batches
        combined = np.vstack(region_points)
        print(f"Total points in region: {len(combined)}")
        
        # Convert lon/lat/elevation into XYZ using spherical to cartesian
        mars_radius = 3396000  # Approx Mars radius in meters
        lon_rad = np.deg2rad(combined[:, 0])
        lat_rad = np.deg2rad(combined[:, 1])
        alt = combined[:, 2]
        
        X = (mars_radius + alt) * np.cos(lat_rad) * np.cos(lon_rad)
        Y = (mars_radius + alt) * np.cos(lat_rad) * np.sin(lon_rad)
        Z = (mars_radius + alt) * np.sin(lat_rad)
        
        points = np.column_stack((X, Y, Z))
        
        # Create point cloud
        pcd = o3d.geometry.PointCloud()
        pcd.points = o3d.utility.Vector3dVector(points)
        
        # Generate descriptive filename
        region_name = f"mars_{min_lon}E-{max_lon}E_{min_lat}N-{max_lat}N"
        output_file = os.path.join(output_folder, f"{region_name}.ply")
        
        # Save the point cloud
        print(f"Writing point cloud to: {output_file}")
        success = o3d.io.write_point_cloud(output_file, pcd)
        
        if success:
            print(f"✅ Export complete! File saved as '{output_file}'")
            
            # Create metadata file
            metadata_path = os.path.join(output_folder, f"{region_name}_metadata.txt")
            with open(metadata_path, 'w') as meta_file:
                meta_file.write("MARS TOPOGRAPHY POINT CLOUD - REGION EXTRACT\n")
                meta_file.write(f"Generated on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
                meta_file.write("REGION BOUNDARIES:\n")
                meta_file.write(f"  Longitude: {min_lon}°E to {max_lon}°E ({360-max_lon}°W to {360-min_lon}°W)\n")
                meta_file.write(f"  Latitude: {min_lat}°N to {max_lat}°N\n\n")
                meta_file.write("FILE INFORMATION:\n")
                meta_file.write(f"  Points: {len(points)}\n")
                meta_file.write(f"  Mars radius used: {mars_radius} meters\n\n")
                
                # Calculate statistical information
                min_x, min_y, min_z = np.min(points, axis=0)
                max_x, max_y, max_z = np.max(points, axis=0)
                min_alt = np.min(alt)
                max_alt = np.max(alt)
                mean_alt = np.mean(alt)
                
                meta_file.write("STATISTICS:\n")
                meta_file.write(f"  Altitude range: {min_alt:.2f}m to {max_alt:.2f}m\n")
                meta_file.write(f"  Mean altitude: {mean_alt:.2f}m\n")
                meta_file.write(f"  Cartesian bounds (meters):\n")
                meta_file.write(f"    X: {min_x:.2f} to {max_x:.2f}\n")
                meta_file.write(f"    Y: {min_y:.2f} to {max_y:.2f}\n")
                meta_file.write(f"    Z: {min_z:.2f} to {max_z:.2f}\n")
            
            print(f"✅ Metadata file created: {metadata_path}")
        else:
            print(f"❌ Failed to write point cloud")
    else:
        print("❌ No points found in the specified region")

except Exception as e:
    print(f"❌ Error occurred: {str(e)}")
    print("Detailed traceback:")
    traceback.print_exc()
# Out:
# Created output directory: D:\MARS FILES\ultimateMOLA_topography\region_topography
# Found 770 .d files to process
# Processing batch 1: files 1 to 50
#   Found 299504 points in region for this batch
# Processing batch 2: files 51 to 100
#   Found 438441 points in region for this batch
# Processing batch 3: files 101 to 150
#   Found 420946 points in region for this batch
# Processing batch 4: files 151 to 200
#   Found 437569 points in region for this batch
# Processing batch 5: files 201 to 250
#   Found 405771 points in region for this batch
# Processing batch 6: files 251 to 300
#   Found 434768 points in region for this batch
# Processing batch 7: files 301 to 350
#   Found 421198 points in region for this batch
# Processing batch 8: files 351 to 400
#   Found 333607 points in region for this batch
# Processing batch 9: files 401 to 450
#   Found 398845 points in region for this batch
# Processing batch 10: files 451 to 500
#   Found 412465 points in region for this batch
# Processing batch 11: files 501 to 550
#   Found 417834 points in region for this batch
# Processing batch 12: files 551 to 600
#   Found 393776 points in region for this batch
# Processing batch 13: files 601 to 650
#   Found 396851 points in region for this batch
# Processing batch 14: files 651 to 700
#   Found 396025 points in region for this batch
# Processing batch 15: files 701 to 750
#   Found 391529 points in region for this batch
# Processing batch 16: files 751 to 770
#   Found 156188 points in region for this batch
# Total points in region: 6155317
# Writing point cloud to: D:\MARS FILES\ultimateMOLA_topography\region_topography\mars_230E-255E_-17N-10N.ply
# ✅ Export complete! File saved as 'D:\MARS FILES\ultimateMOLA_topography\region_topography\mars_230E-255E_-17N-10N.ply'
# ✅ Metadata file created: D:\MARS FILES\ultimateMOLA_topography\region_topography\mars_230E-255E_-17N-10N_metadata.txt
